# %%
from wordcloud import WordCloud, STOPWORDS

alice_novel = open("alice_in_wonderland.txt")
alice_novel = alice_novel.read()

stopwords=set(STOPWORDS)
print(stopwords)
print(len(stopwords))
stopwords.add('alice')
alice_wc = WordCloud(background_color='green', max_words=2000, stopwords = stopwords,collocations=False)
alice_wc.generate(alice_novel)
# Out:
# {'which', 'no', "hadn't", 'with', 'by', "wouldn't", 'once', 'it', 'like', "aren't", 'here', 'some', 'between', 'any', 'otherwise', 'ought', 'am', 'were', "she'd", 'the', "you'd", 'does', 'me', "there's", 'hence', 'ourselves', 'but', 'who', 'being', "why's", 'below', 'an', 'its', "here's", 'for', 'again', 'theirs', 'having', "can't", "i've", 'our', "they'll", 'these', 'have', 'has', 'itself', 'was', 'you', 'about', "i'm", "they've", "how's", 'then', "shan't", 'because', "she's", 'into', 'yourself', "he'd", 'yourselves', 'until', "they'd", "she'll", 'they', 'through', 'she', 'to', 'been', 'her', 'that', "it's", 'my', 'off', 'down', 'this', 'do', 'when', "shouldn't", 'would', 'in', "isn't", 'since', 'from', "let's", 'few', 'how', 'his', 'not', "haven't", "mustn't", 'r', 'while', "didn't", "doesn't", "hasn't", 'com', "i'd", 'could', 'after', "couldn't", 'shall', 'why', 'also', 'are', "don't", 'your', 'before', 'ever', "you're", 'we', 'had', 'their', 'cannot', 'should', 'them', 'against',
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10,10])
plt.imshow(alice_wc)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

dataset = pd.read_csv('auto-mpg.csv')
sns.regplot(x='weight',y='displacement',data=dataset,color='black')
plt.show()

# %%
dataset.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(15,10))
dataset = pd.read_csv('auto-mpg.csv')
sns.set(font_scale=1.5) #give bg style
sns.regplot(x='mpg',y='displacement',data=dataset,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(15,10))
dataset = pd.read_csv('auto-mpg.csv')
sns.set(font_scale=1.5) #give bg style
sns.regplot(x='mpg',y='displacement',data=dataset,color='red',scatter_kws={'s':200}) #scatter_kws={'s':200} bif size of point
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = np.random.randint(low = 1,high = 100,size = (10, 10))

print("The Data to be plotted:\n")
print(data)

sns.heatmap(data)

plt.show()
# Out:
# The Data to be plotted:
#
# [[26 16 91 45 13 14 11 50 30 90]
#  [15 23 77 14 92 73 29 39 23  4]
#  [40 37 83 75 12 84 65 89 25 75]
#  [51 13 57 55 46  8 95 28 72 78]
#  [95 34 31 33 23 90 43  5 65 85]
#  [51 22 66 51  9 52 72 51 76 40]
#  [78 43 70 40 10 26 15 80 27 99]
#  [20 40 22  9 87 47 64 55 82 78]
#  [56 81 32 23 87 54 97 27 30 86]
#  [43 24 28 73 69 71 62 48 78 84]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = np.random.randint(low = 1,high = 100,size = (10, 10))

print("The Data to be plotted:\n")
print(data)

sns.heatmap(data,vmin=30,vmax=70) #vmin=30,vmax=70 range 
 
plt.show()
# Out:
# The Data to be plotted:
#
# [[89 26  9 91 83 76 78 14 54  6]
#  [36  2 52 89 61  4 83 62 89 88]
#  [15 60 32 14 59 52 10 65 59 64]
#  [59 87 97 82 89 21 10 36 27 26]
#  [60 51 47 89 12  3 69 53 85 73]
#  [21 89 37 19  6 56 65 43 17 24]
#  [59  8 23 62 61 71 55 30 51 72]
#  [42 69 78 88 74  7 89 30  9 92]
#  [55 37 79 88 50 59  8  5 45 53]
#  [38 34 61 86  1  3 64 43 66 57]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = np.random.randint(low = 1,high = 100,size = (10, 10))

print("The Data to be plotted:\n")
print(data)

sns.heatmap(data,vmin=30,vmax=70,cmap="tab20",annot=True) #annot=True give number on color

plt.show()
# Out:
# The Data to be plotted:
#
# [[19 44 51 91 83 36 46 56 67 25]
#  [ 6 14 94 53 95 98 78 48 77 95]
#  [37 76 21 81 43 34 20 65 67 79]
#  [81 49 96 82 50 74 69 74 42 33]
#  [44 99 63 77 44 38 46 59  4 53]
#  [53 17 62 61 91 47 18 46 91 62]
#  [ 6 60 65 37 59 54 53 92  1 16]
#  [49 49 53 67 66  6 90  9 63 79]
#  [88 53 98 42 77 57 20 70 62 38]
#  [89 52 22 98 70 54  6 30 85 44]]
